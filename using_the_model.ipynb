# %%
from forecast_pipeline import ejecutar_pronostico

# Configura los parámetros según necesites
ejecutar_pronostico('aggregated_data4.csv', 'mi_modelo.h5', 'CABRILLA', 'BAJA CALIFORNIA SUR', 'LA PAZ', 4)
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step
# /home/rcavieses/DLM-mexican-fish-catch-forecast/ia_model/forecasting.py:56: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
# ...
