# %%
# Importaciones necesarias de tus otros módulos
from ia_model.data_preparation import load_data
import config as cfg
# Importación del nuevo módulo de pronóstico
from ia_model.forecasting import pronosticar_y_graficar
# Out:
# WARNING:tensorflow:From c:\Users\ricar\anaconda3\envs\pro24\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Carga de los datos
df = load_data('aggregated_data2.csv')

# Definir parámetros para el pronóstico
nombre_producto = 'CABRILLA'  # Change this for your product
nombre_estado = 'BAJA CALIFORNIA SUR'
nombre_oficina = 'SAN CARLOS'
n_pasos = 1  # Número de meses a pronosticar

# Realizar y visualizar el pronóstico
pronosticar_y_graficar(df, nombre_producto, nombre_estado, nombre_oficina, n_pasos, cfg.MODEL_PATH, cfg.SCALER_X_PATH, cfg.SCALER_Y_PATH)
# Out:
# WARNING:tensorflow:From c:\Users\ricar\anaconda3\envs\pro24\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 [==============================] - 0s 335ms/step
# c:\Users\ricar\OneDrive\Documentos\Proyectos\CEDO\Main\ia_model\forecasting.py:31: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   fechas_historicas = pd.date_range(start=serie_historica.index.min(), periods=len(serie_historica), freq='M')
# c:\Users\ricar\OneDrive\Documentos\Proyectos\CEDO\Main\ia_model\forecasting.py:33: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   fechas_futuras = pd.date_range(start=ultimo_mes + pd.DateOffset(months=1), periods=n_pasos, freq='M')

# %%
2023-1993
# Out:
# 30
